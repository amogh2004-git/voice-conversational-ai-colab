# %%
# Install browser automation
# !apt update -qq
# !apt install -y chromium-browser
# !pip install playwright
# !playwright install chromium

print(" Playwright browser ready!")
# Out:
# 51 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor libfuse3-3 libudev1 snapd squashfs-tools systemd-hwe-hwdb udev
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor chromium-browser libfuse3-3 snapd squashfs-tools systemd-hwe-hwdb
#   udev
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 7 newly installed, 0 to remove and 50 not upgraded.
# Need to get 35.2 MB of archives.
# After this operation, 136 MB of additional disk space will be used.
# ...

# %%
# Install + Browser Tools
# !apt update -qq
# !apt install -y chromium-browser
# !pip install -q playwright groq
# !playwright install chromium

from playwright.async_api import async_playwright
import asyncio
from groq import Groq

# Groq client (paste YOUR key)
client = Groq(api_key="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")

print(" Browser agent + Groq ready!")
# Out:
# 50 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium-browser is already the newest version (1:85.0.4183.83-0ubuntu2.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
#  Browser agent + Groq ready!

# %%
# Test agent
goal = "Open Wikipedia Artificial Intelligence page"
result = await browser_agent(goal)
print("\n Mission complete:")
print(result)
# Out:
#  LLM: {"action": "open_url", "param": "https://en.wikipedia.org/wiki/Artificial_intelligence"}
#
#  Mission complete:
#  Browser error: BrowserType.launch: Target page, context or browser has been closed
# Browser logs:
#
# ...
